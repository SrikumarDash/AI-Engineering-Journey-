# %%
import pandas

# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/srikumar/AI/Pandas'

# %%
ls
# Out:
# Demo_Readme.txt  nyc_weather.csv  Pandas01.ipynb

# %%
df = pd.read_csv("nyc_weather.csv")
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.tail(2)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 29             257
# 30             241

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df['CloudCover']
# Out:
# 0     5
# 1     3
# 2     1
# 3     3
# 4     0
# 5     0
# 6     3
# 7     8
# 8     8
# 9     7
# 10    1
# 11    4
# 12    0
# 13    7
# 14    2
# 15    7
# 16    6
# 17    2
# 18    1
# 19    2
# 20    1
# 21    3
# 22    8
# 23    3
# 24    2
# 25    2
# 26    3
# 27    1
# 28    4
# 29    0
# 30    0
# Name: CloudCover, dtype: int64

# %%
df[2:5]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 2             277
# 3             345
# 4             333

# %%
df[:][2:5]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 2             277
# 3             345
# 4             333

# %%
df[2:5]['Temperature']
# Out:
# 2    40
# 3    25
# 4    20
# Name: Temperature, dtype: int64

# %%
df[20:30]['Events']
# Out:
# 20         NaN
# 21        Snow
# 22    Fog-Snow
# 23        Snow
# 24         NaN
# 25         NaN
# 26        Rain
# 27         NaN
# 28         NaN
# 29         NaN
# Name: Events, dtype: object

# %%
df.head(3)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277

# %%
df[['EST', 'Humidity', 'WindSpeedMPH']][:4]
# Out:
#         EST  Humidity  WindSpeedMPH
# 0  1/1/2016        52           8.0
# 1  1/2/2016        46           7.0
# 2  1/3/2016        47           8.0
# 3  1/4/2016        44           9.0

# %%
df['Temperature'].mean()
# Out:
# np.float64(34.67741935483871)

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df.Temperature
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %%
df.Temperature >40
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26     True
# 27    False
# 28    False
# 29    False
# 30     True
# Name: Temperature, dtype: bool

# %%
df[df.Temperature > 40]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 14                9           5.0               T           2    NaN
# 15                8           7.0            0.24           7   Rain
# ...

# %%
df[df.Temperature > 40].Temperature.max()
# Out:
# 50

# %%
df[df.Temperature == df.Temperature.max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
(df.Temperature == df.Temperature.max())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# Name: Temperature, dtype: bool

# %%
import pandas as pd
df = pd.read_csv("nyc_weather.csv")
df[df.Temperature == df.Temperature.max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
df[df.Temperature==df['Temperature'].max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
df[df.Temperature==df.Temperature.max()].Humidity
# Out:
# 9    71
# Name: Humidity, dtype: int64

# %%
df['EST'][df.Temperature == df.Temperature.max()]
# Execution started from right to left
# right side condition [] part - gives a list of true false values 
# then if you add ['EST'] it gives you the value instead of row
# Out:
# 9    1/10/2016
# Name: EST, dtype: object

# %%
df[['Temperature','EST']][df.Temperature==df.Temperature.max()]
# Out:
#    Temperature        EST
# 9           50  1/10/2016

# %%
df['Humidity'].mean()
# Out:
# np.float64(51.67741935483871)

# %%
df['Humidity']
# Out:
# 0     52
# 1     46
# 2     47
# 3     44
# 4     41
# 5     35
# 6     33
# 7     64
# 8     77
# 9     71
# 10    37
# 11    53
# 12    42
# 13    47
# 14    62
# 15    70
# 16    66
# 17    53
# 18    42
# 19    49
# 20    45
# 21    41
# 22    78
# 23    53
# 24    54
# 25    56
# 26    45
# 27    51
# 28    50
# 29    46
# 30    52
# Name: Humidity, dtype: int64

# %%
df[['Humidity','CloudCover']][2:5]
# Out:
#    Humidity  CloudCover
# 2        47           1
# 3        44           3
# 4        41           0

# %%
df[2:5]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 2             277
# 3             345
# 4             333

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.head(2)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
#
#    WindDirDegrees
# 0             281
# 1             275

# %%
df.tail(3)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 28             298
# 29             257
# 30             241

# %%
a = df['Temperature'].max()
print(a)
# Out:
# 50

# %%
df[df['Temperature'] == a]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
df[['DewPoint','Events'][:4]]
# Out:
#     DewPoint    Events
# 0         23       NaN
# 1         18       NaN
# 2         21       NaN
# 3          9       NaN
# 4         -3       NaN
# 5          4       NaN
# 6         11       NaN
# 7         29       NaN
# 8         38      Rain
# 9         46      Rain
# 10         8       NaN
# 11        15       NaN
# 12         4       NaN
# 13        12       NaN
# 14        31       NaN
# 15        37      Rain
# 16        23  Fog-Snow
# 17         6      Snow
# 18         3       NaN
# 19        15       NaN
# 20        11       NaN
# 21         6      Snow
# 22        21  Fog-Snow
# 23        11      Snow
# 24        18       NaN
# 25        29       NaN
# 26        22      Rain
# 27        20       NaN
# 28        21       NaN
# 29        16       NaN
# 30        28       NaN

# %%
df[['EST','DewPoint']][:4]
# Out:
#         EST  DewPoint
# 0  1/1/2016        23
# 1  1/2/2016        18
# 2  1/3/2016        21
# 3  1/4/2016         9

# %%
df[['WindSpeedMPH']][15:17]
# Out:
#     WindSpeedMPH
# 15           7.0
# 16           6.0

# %%
df = pd.read_csv("nyc_weather.csv")

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.loc('Humidity'==47)
#understand what this code means from google if you want to.. unknown to me

# %%
df.set_index('Humidity',inplace=True)
df
# Out:
#           index        EST  Temperature  DewPoint  Sea Level PressureIn  \
# Humidity
# 52            0   1/1/2016           38        23                 30.03
# 46            1   1/2/2016           36        18                 30.02
# 47            2   1/3/2016           40        21                 29.86
# 44            3   1/4/2016           25         9                 30.05
# 41            4   1/5/2016           20        -3                 30.57
# 35            5   1/6/2016           33         4                 30.50
# 33            6   1/7/2016           39        11                 30.28
# 64            7   1/8/2016           39        29                 30.20
# 77            8   1/9/2016           44        38                 30.16
# 71            9  1/10/2016           50        46                 29.59
# 37           10  1/11/2016           33         8                 29.92
# 53           11  1/12/2016           35        15                 29.85
# ...

# %%
df.reset_index(inplace = True)
df
# Out:
#     index        EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0       0   1/1/2016           38        23        52                 30.03
# 1       1   1/2/2016           36        18        46                 30.02
# 2       2   1/3/2016           40        21        47                 29.86
# 3       3   1/4/2016           25         9        44                 30.05
# 4       4   1/5/2016           20        -3        41                 30.57
# 5       5   1/6/2016           33         4        35                 30.50
# 6       6   1/7/2016           39        11        33                 30.28
# 7       7   1/8/2016           39        29        64                 30.20
# 8       8   1/9/2016           44        38        77                 30.16
# 9       9  1/10/2016           50        46        71                 29.59
# 10     10  1/11/2016           33         8        37                 29.92
# ...

# %%
df[0:1]
# but this gives error - df[[0:5]]
# when you are fetching by columns, use double square brackets to avoid confusion between df['col1'] and df[['col1', 'col2']]
# Out:
#           index       EST  Temperature  DewPoint  Sea Level PressureIn  \
# Humidity
# 52            0  1/1/2016           38        23                 30.03
#
#           VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# Humidity
# 52                     10           8.0               0           5    NaN
#
#           WindDirDegrees
# Humidity
# 52                   281
